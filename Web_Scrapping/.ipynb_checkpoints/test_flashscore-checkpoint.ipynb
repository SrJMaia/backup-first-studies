# %%
from urllib.request import urlopen, urlretrieve, Request
import urllib
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.flashscore.pt/equipa/flamengo/WjxY29qB/resultados/"

# %%
limiter = "/r/x/comments"
img_ref = "https://i.redd.it/"
gif_ref = "https://i.imgur.com/"
img_n = 0
gif_n = 0
#html = urlopen(url).read().decode("utf-8")
html = requests.get(url, headers=headers, cookies=cookies)
html.encoding = "UTF-8"
soup = BeautifulSoup(html.content)
find_all_a1 = soup.find_all("a")
first = True
for k in range(5):
    if first:
        for i in range(len(find_all_a1)):
            if i % 2 != 0:
                continue
            try:
                if find_all_a1[i]["href"][:len(limiter)] == limiter:
                    #html2 = urlopen(url3+find_all_a1[i]["href"]).read().decode("utf-8")
                    html2 = requests.get(url3+find_all_a1[i]["href"], headers=headers)
                    html2.encoding = "UTF-8"
                    soup2 = BeautifulSoup(html2.content, "lxml")
                    find_all_a2 = soup2.find_all("a")
                    for j in range(len(find_all_a2)):
                        img = ""
                        gif = ""
                        print(find_all_a2[j]["href"][:len(img_ref)])
                        try:
                            if find_all_a2[j]["href"][:len(img_ref)] == img_ref:
                                img = find_all_a2[j]["href"]
                                if img != "":
                                    urlretrieve(str(img), f"images/{img_n}.png")
                                    img_n += 1
                                    break
                            elif find_all_a2[j]["href"][:len(gif_ref)] == gif_ref:
                                gif = img = find_all_a2[j]["href"]
                                if gif != "":
                                    urlretrieve(str(gif), f"images/{gif_n}.mp4")
                                    gif_n += 1
                                    break
                                
                        except:
                            continue
            except:
                continue
        first = False
    else:
        for i in range(len(find_all_a1)):
            try:
                next_page = find_all_a1[i]["href"]
                if next_page[:len(url2)] == url2:
                    #html = urlopen(next_page).read().decode("utf-8")
                    html = requests.get(next_page, headers=headers)
                    html.encoding = "UTF-8"
                    soup = BeautifulSoup(html.content, "lxml")
                    find_all_a1 = soup.find_all("a")
                    break
            except:
                continue
                
        for i in range(len(find_all_a1)):
            if i % 2 != 0:
                continue
            try:
                if find_all_a1[i]["href"][:len(limiter)] == limiter:
                    #html2 = urlopen(url3+find_all_a1[i]["href"]).read().decode("utf-8")
                    tmml2 = requests.get(url3+find_all_a1[i]["href"], headers=headers)
                    html2.encoding = "UTF-8"
                    soup2 = BeautifulSoup(html2.content, "lxml")
                    find_all_a2 = soup2.find_all("a")
                    for j in range(len(find_all_a2)):
                        img = ""
                        try:
                            if find_all_a2[j]["href"][:len(img_ref)] == img_ref:
                                img = find_all_a2[j]["href"]
                                if img != "":
                                    urlretrieve(str(img), f"images/{img_n}.png")
                                    img_n += 1
                                    break
                        except:
                            continue
            except:
                continue

# %%
from selenium import webdriver
from time import sleep
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
option = Options()

option.add_argument("--disable-infobars")
option.add_argument("start-maximized")
option.add_argument("--disable-extensions")

# Pass the argument 1 to allow and 2 to block
option.add_experimental_option("prefs", { 
    "profile.default_content_setting_values.notifications": 1 
})

navegador = webdriver.Chrome(options=option, executable_path='C:\\Users\\johnk\\AppData\\Local\\Programs\\Python\\Python39\\chromedriver.exe')
        
navegador.get(test_url)

navegador.find_element_by_xpath('/html/body/div[3]/div/form/div/button[2]').click()

# %%
soup = BeautifulSoup(navegador.page_source)

# %%
option = Options()

option.add_argument("--disable-infobars")
option.add_argument("start-maximized")
option.add_argument("--disable-extensions")

# Pass the argument 1 to allow and 2 to block
option.add_experimental_option("prefs", { 
    "profile.default_content_setting_values.notifications": 1 
})

navegador = webdriver.Chrome(options=option, executable_path='C:\\Users\\johnk\\AppData\\Local\\Programs\\Python\\Python39\\chromedriver.exe')
        
navegador.get(test_url)

sleep(1)

# Accept
navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div[4]/div[2]/button[1]').click()
sleep(1)
# First image
navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/main/div[1]/div/div[1]/div[3]').click()
sleep(0.5)
for i in range(200):
    try:
        img = navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div[1]/div[1]/div/img')
        src = img.get_attribute('src')
        urlretrieve(src, f'images/{i}.png')
    except:
        navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div[1]/button[2]').click()
    else:
        navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div[1]/button[2]').click()
    sleep(0.1)
