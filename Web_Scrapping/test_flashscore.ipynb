# %%
from urllib.request import urlopen, urlretrieve, Request
import urllib
import requests

from bs4 import BeautifulSoup
#from selenium import webdriver
from time import sleep
#from selenium import webdriver
#from selenium.webdriver.chrome.options import Options

# %%
url = "https://www.betfair.com/sport/football/conmebol-copa-libertadores/cerro-porteno-x-fluminense/30609246"

# %%
html = requests.get(url)
html.encoding = "UTF-8"
soup = BeautifulSoup(html.content)
result = soup.find_all("span")#, class_="event__match event__match--static event__match--last event__match--twoLine")

# %%
result
# Out:
# [<span class="ssc-shpb" type="button"></span>,
#  <span class="ssc-lkh ssc-sprite"></span>,
#  <span>Join Now</span>,
#  <span class="checkmark"></span>,
#  <span class="ssc-rmb-text">Remember me</span>,
#  <span class="ssc-lsf ssc-sprite ssc-fen_gb"></span>,
#  <span class="ssc-aru ssc-sprite"></span>,
#  <span class="ssc-ldf ssc-sprite ssc-fen_GB"></span>,
#  <span class="ssc-ldf ssc-sprite ssc-fie"></span>,
#  <span class="ssc-ldf ssc-sprite ssc-fde"></span>,
#  <span class="ssc-ldf ssc-sprite ssc-fes_419"></span>,
#  <span class="ssc-ldf ssc-sprite ssc-fpt_BR"></span>,
#  <span class="ssc-ldf ssc-sprite ssc-fru"></span>,
#  <span class="ssc-ldf ssc-sprite ssc-fhu"></span>,
#  <span class="ssc-ldf ssc-sprite ssc-ffi"></span>,
#  <span class="ssc-ldf ssc-sprite ssc-fno"></span>,
#  <span class="sportIcon-6423"></span>,
#  <span class="sportName">American Football</span>,
#  <span class="sportIcon-3988"></span>,
#  <span class="sportName">Athletics</span>,
#  <span class="sportIcon-61420"></span>,
#  <span class="sportName">Australian Rules</span>,
#  <span class="sportIcon-7511"></span>,
#  <span class="sportName">Baseball</span>,
#  <span class="sportIcon-7522"></span>,
#  <span class="sportName">Basketball</span>,
#  <span class="sportIcon-2872194"></span>,
#  <span class="sportName">Beach Volleyball</span>,
#  <span class="sportIcon-6"></span>,
#  <span class="sportName">Boxing</span>,
#  <span class="sportIcon-4"></span>,
#  <span class="sportName">Cricket</span>,
#  <span class="sportIcon-27388198"></span>,
#  <span class="sportName">Current Affairs</span>,
#  <span class="sportIcon-11"></span>,
#  <span class="sportName">Cycling</span>,
#  <span class="sportIcon-3503"></span>,
#  <span class="sportName">Darts</span>,
#  <span class="sportIcon-27454571"></span>,
#  <span class="sportName">Esports</span>,
#  <span class="sportIcon-1"></span>,
#  <span class="sportName">Football</span>,
#  <span class="sportIcon-2152880"></span>,
#  <span class="sportName">Gaelic Games</span>,
#  <span class="sportIcon-3"></span>,
#  <span class="sportName">Golf</span>,
#  <span class="sportIcon-4339"></span>,
#  <span class="sportName">Greyhound Racing</span>,
#  <span class="sportIcon-468328"></span>,
#  <span class="sportName">Handball</span>,
#  <span class="sportIcon-7523"></span>,
#  <span class="sportName">Hockey</span>,
#  <span class="sportIcon-7"></span>,
#  <span class="sportName">Horse Racing</span>,
#  <span class="sportIcon-7524"></span>,
#  <span class="sportName">Ice Hockey</span>,
#  <span class="sportIcon-26420387"></span>,
#  <span class="sportName">Mixed Martial Arts</span>,
#  <span class="sportIcon-8"></span>,
#  <span class="sportName">Motor Sport</span>,
#  <span class="sportIcon-606611"></span>,
#  <span class="sportName">Netball</span>,
#  <span class="sportIcon-27589895"></span>,
#  <span class="sportName">Olympics</span>,
#  <span class="sportIcon-2378961"></span>,
#  <span class="sportName">Politics</span>,
#  <span class="sportIcon-1477"></span>,
#  <span class="sportName">Rugby League</span>,
#  <span class="sportIcon-5"></span>,
#  <span class="sportName">Rugby Union</span>,
#  <span class="sportIcon-6422"></span>,
#  <span class="sportName">Snooker</span>,
#  <span class="sportIcon-10"></span>,
#  <span class="sportName">Special Bets</span>,
#  <span class="sportIcon-4726642"></span>,
#  <span class="sportName">Surfing</span>,
#  <span class="sportIcon-620576"></span>,
#  <span class="sportName">Swimming</span>,
#  <span class="sportIcon-2593174"></span>,
#  <span class="sportName">Table Tennis</span>,
#  <span class="sportIcon-2"></span>,
#  <span class="sportName">Tennis</span>,
#  <span class="sportIcon-27065662"></span>,
#  <span class="sportName">Triathlon</span>,
#  <span class="sportIcon-998917"></span>,
#  <span class="sportName">Volleyball</span>,
#  <span class="sportIcon-2901849"></span>,
#  <span class="sportName">Water Polo</span>,
#  <span class="sportIcon-ALLSPORTS"></span>,
#  <span class="divider"> </span>,
#  <span class="sportName">All Sports (36)</span>,
#  <span class="sportIcon-home"></span>,
#  <span class="sportName">Home</span>,
#  <span class="sportIcon-inplay"></span>,
#  <span class="sportName">In-Play</span>,
#  <span class="sportIcon-cashout"></span>,
#  <span class="sportName">Cash Out</span>,
#  <span class="sportIcon-1"></span>,
#  <span class="sportName">Promotions</span>,
#  <span class="sportIcon-1"></span>,
#  <span class="sportName">Beat The Drop</span>,
#  <span class="sportIcon-1"></span>,
#  <span class="sportName">Football</span>,
#  <span class="sportIcon-7"></span>,
#  <span class="sportName">Horse Racing</span>,
#  <span class="sportIcon-4339"></span>,
#  <span class="sportName">Greyhound Racing</span>,
#  <span class="sportIcon-3503"></span>,
#  <span class="sportName">Darts</span>,
#  <span class="sportIcon-26420387"></span>,
#  <span class="sportName">Mixed Martial Arts</span>,
#  <span class="sportIcon-6"></span>,
#  <span class="sportName">Boxing</span>,
#  <span class="sportIcon-2"></span>,
#  <span class="sportName">Tennis</span>,
#  <span class="sportIcon-2378961"></span>,
#  <span class="sportName">Politics</span>,
#  <span class="sportIcon-3"></span>,
#  <span class="sportName">Golf</span>,
#  <span class="arrow"><span class="ico"><!-- --></span></span>,
#  <span class="ico"><!-- --></span>,
#  <span class="title">Betslip</span>,
#  <span class="bet-count">0</span>,
#  <span class="counter">0</span>,
#  <span class="counter">0</span>,
#  <span class="max-payout-exceeded-error-amount">£-1.00</span>,
#  <span class="stake-return-header">Stake &amp; Returns</span>,
#  <span class="ui-new-label">NEW</span>,
#  <span class="stake-return-header">Stake &amp; Returns</span>,
#  <span class="arrow"></span>,
#  <span class="left-title">Multiples</span>,
#  <span class="right-title">Stake &amp; Returns</span>,
#  <span class="cashout-icon"> </span>,
#  <span class="cashout-text">Cash Out available</span>,
#  <span class="arrow"></span>,
#  <span class="left-title">Forecast &amp; Tricast</span>,
#  <span class="right-title">Stake</span>,
#  <span>Total Stake: </span>,
#  <span class="total-stake-value" data-value="0">
#  £0.00
#  </span>,
#  <span>Potential returns: </span>,
#  <span class="total-payout-value">£0.00</span>,
#  <span class="bonus-icon cta"></span>,
#  <span class="com-toggler disabled"><span class="circle"></span></span>,
#  <span class="circle"></span>,
#  <span class="com-toggler disabled"><span class="circle"></span></span>,
#  <span class="circle"></span>,
#  <span class="com-toggler disabled"><span class="circle"></span></span>,
#  <span class="circle"></span>,
#  <span class="max-payout-exceeded-error-amount">£-1.00</span>,
#  <span class="stake-return-header">Stake &amp; Returns</span>,
#  <span class="ui-new-label">NEW</span>,
#  <span class="stake-return-header">Stake &amp; Returns</span>,
#  <span class="arrow"></span>,
#  <span class="left-title">Multiples</span>,
#  <span class="right-title">Stake &amp; Returns</span>,
#  <span class="cashout-icon"> </span>,
#  <span class="cashout-text">Cash Out available</span>,
#  <span class="arrow"></span>,
#  <span class="left-title">Forecast &amp; Tricast</span>,
#  <span class="right-title">Stake</span>,
#  <span>Total Stake: </span>,
#  <span class="total-stake-value" data-value="0">
#  £0.00
#  </span>,
#  <span>Potential returns: </span>,
#  <span class="total-payout-value">£0.00</span>,
#  <span class="com-toggler disabled"><span class="circle"></span></span>,
#  <span class="circle"></span>,
#  <span title="CONMEBOL Copa Libertadores">CONMEBOL Copa Libertadores</span>,
#  <span class="ui-score-container">
#  <span class="home-score ui-score-home"></span>
#  </span>,
#  <span class="home-score ui-score-home"></span>,
#  <span class="time ui-time-stop-format"></span>,
#  <span class="ui-score-container">
#  <span class="away-score ui-score-away"></span>
#  </span>,
#  <span class="away-score ui-score-away"></span>,
#  <span class="ui-score-container">
#  <div class="generic-match-status">
#  <div class="generic-match-status-content ">
#  <span class="ui-when-event-inprogress">
#  <span class="time inPlayFallback">In-Play</span>
#  </span>
#  <span class="ui-when-event-finished">
#  Match Over
#  </span>
#  </div>
#  </div>
#  </span>,
#  <span class="ui-when-event-inprogress">
#  <span class="time inPlayFallback">In-Play</span>
#  </span>,
#  <span class="time inPlayFallback">In-Play</span>,
#  <span class="ui-when-event-finished">
#  Match Over
#  </span>,
#  <span class="ui-no-score">
#  <div class="generic-match-status">
#  <div class="generic-match-status-content ">
#  <span class="ui-when-event-inprogress">
#  <span class="time inPlayFallback">In-Play</span>
#  </span>
#  <span class="ui-when-event-finished">
#  Match Over
#  </span>
#  </div>
#  </div>
#  </span>,
#  <span class="ui-when-event-inprogress">
#  <span class="time inPlayFallback">In-Play</span>
#  </span>,
#  <span class="time inPlayFallback">In-Play</span>,
#  <span class="ui-when-event-finished">
#  Match Over
#  </span>,
#  <span class="ui-when-event-inprogress">
#  <span class="ui-countdown " data-countdown="11" data-type="default">
#  Starting in 11′
#  </span>
#  </span>,
#  <span class="ui-countdown " data-countdown="11" data-type="default">
#  Starting in 11′
#  </span>,
#  <span class="ui-when-event-finished">
#  Match Over
#  </span>,
#  <span class="ui-ball-box">BALL <span class="ui-over-number"></span>.<span class="ui-over-ball-number"></span></span>,
#  <span class="ui-over-number"></span>,
#  <span class="ui-over-ball-number"></span>,
#  <span class="ui-bowler-name"></span>,
#  <span class="ui-batsman-name"></span>,
#  <span class="ui-event-message"></span>,
#  <span class="icon"> </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="play-full-icon">
#  Play Now
#  </span>,
#  <span class="info-icon"></span>,
#  <span class="cs-close-iframe close-icon"></span>,
#  <span class="overlay">
#  <span class="box"></span>
#  <span class="message"></span>
#  </span>,
#  <span class="box"></span>,
#  <span class="message"></span>,
#  <span class="home-team-name" title="Boca Juniors">Boca Juniors</span>,
#  <span class="score"><span class="ui-score-container inplaynow-score score-template-default">
#  <span class="ui-score-home">
#  </span>
#  <span class="separator">-</span> <span class="ui-score-away">
#  </span> </span>
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span></span>,
#  <span class="ui-score-container inplaynow-score score-template-default">
#  <span class="ui-score-home">
#  </span>
#  <span class="separator">-</span> <span class="ui-score-away">
#  </span> </span>,
#  <span class="ui-score-home">
#  </span>,
#  <span class="separator">-</span>,
#  <span class="ui-score-away">
#  </span>,
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span>,
#  <span class="separator">-</span>,
#  <span class="away-team-name" title="Atletico MG">Atletico MG</span>,
#  <span class="status">
#  <span class="ui-score-container">
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span> </span>
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="11">
#  Starting in 11′
#  </span> </span> </span>,
#  <span class="ui-score-container">
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span> </span>,
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span>,
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="11">
#  Starting in 11′
#  </span> </span>,
#  <span class="date ui-countdown" data-countdown="11">
#  Starting in 11′
#  </span>,
#  <span class="arrow"></span>,
#  <span class="overlay">
#  <span class="box"></span>
#  <span class="message"></span>
#  </span>,
#  <span class="box"></span>,
#  <span class="message"></span>,
#  <span class="home-team-name" title="Sao Paulo">Sao Paulo</span>,
#  <span class="score"><span class="ui-score-container inplaynow-score score-template-default">
#  <span class="ui-score-home">
#  </span>
#  <span class="separator">-</span> <span class="ui-score-away">
#  </span> </span>
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span></span>,
#  <span class="ui-score-container inplaynow-score score-template-default">
#  <span class="ui-score-home">
#  </span>
#  <span class="separator">-</span> <span class="ui-score-away">
#  </span> </span>,
#  <span class="ui-score-home">
#  </span>,
#  <span class="separator">-</span>,
#  <span class="ui-score-away">
#  </span>,
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span>,
#  <span class="separator">-</span>,
#  <span class="away-team-name" title="Racing Club">Racing Club</span>,
#  <span class="status">
#  <span class="ui-score-container">
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span> </span>
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="146">
#  20:30
#  </span> </span> </span>,
#  <span class="ui-score-container">
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span> </span>,
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span>,
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="146">
#  20:30
#  </span> </span>,
#  <span class="date ui-countdown" data-countdown="146">
#  20:30
#  </span>,
#  <span class="arrow"></span>,
#  <span class="overlay">
#  <span class="box"></span>
#  <span class="message"></span>
#  </span>,
#  <span class="box"></span>,
#  <span class="message"></span>,
#  <span class="home-team-name" title="Velez Sarsfield">Velez Sarsfield</span>,
#  <span class="score"><span class="ui-score-container inplaynow-score score-template-default">
#  <span class="ui-score-home">
#  </span>
#  <span class="separator">-</span> <span class="ui-score-away">
#  </span> </span>
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span></span>,
#  <span class="ui-score-container inplaynow-score score-template-default">
#  <span class="ui-score-home">
#  </span>
#  <span class="separator">-</span> <span class="ui-score-away">
#  </span> </span>,
#  <span class="ui-score-home">
#  </span>,
#  <span class="separator">-</span>,
#  <span class="ui-score-away">
#  </span>,
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span>,
#  <span class="separator">-</span>,
#  <span class="away-team-name" title="Barcelona (ECU)">Barcelona (ECU)</span>,
#  <span class="status">
#  <span class="ui-score-container">
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span> </span>
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="1451">
#  Tomorrow 18:15
#  </span> </span> </span>,
#  <span class="ui-score-container">
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span> </span>,
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span>,
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="1451">
#  Tomorrow 18:15
#  </span> </span>,
#  <span class="date ui-countdown" data-countdown="1451">
#  Tomorrow 18:15
#  </span>,
#  <span class="arrow"></span>,
#  <span class="overlay">
#  <span class="box"></span>
#  <span class="message"></span>
#  </span>,
#  <span class="box"></span>,
#  <span class="message"></span>,
#  <span class="home-team-name" title="Univ Catolica (Chile)">Univ Catolica (Chile)</span>,
#  <span class="score"><span class="ui-score-container inplaynow-score score-template-default">
#  <span class="ui-score-home">
#  </span>
#  <span class="separator">-</span> <span class="ui-score-away">
#  </span> </span>
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span></span>,
#  <span class="ui-score-container inplaynow-score score-template-default">
#  <span class="ui-score-home">
#  </span>
#  <span class="separator">-</span> <span class="ui-score-away">
#  </span> </span>,
#  <span class="ui-score-home">
#  </span>,
#  <span class="separator">-</span>,
#  <span class="ui-score-away">
#  </span>,
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span>,
#  <span class="separator">-</span>,
#  <span class="away-team-name" title="SE Palmeiras">SE Palmeiras</span>,
#  <span class="status">
#  <span class="ui-score-container">
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span> </span>
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="1451">
#  Tomorrow 18:15
#  </span> </span> </span>,
#  <span class="ui-score-container">
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span> </span>,
#  <span class="event-inplay-state inplay ui-time-stop-format " title="">
#  </span>,
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="1451">
#  Tomorrow 18:15
#  </span> </span>,
#  <span class="date ui-countdown" data-countdown="1451">
#  Tomorrow 18:15
#  </span>,
#  <span class="arrow"></span>,
#  <span class="overlay">
#  <span class="box"></span>
#  <span class="message"></span>
#  </span>,
#  <span class="box"></span>,
#  <span class="message"></span>,
#  <span class="home-team-name" title="River Plate">River Plate</span>,
#  <span class="score"><span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span></span>,
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span>,
#  <span class="separator">-</span>,
#  <span class="away-team-name" title="Argentinos Juniors">Argentinos Juniors</span>,
#  <span class="status">
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="1586">
#  Tomorrow 20:30
#  </span> </span> </span>,
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="1586">
#  Tomorrow 20:30
#  </span> </span>,
#  <span class="date ui-countdown" data-countdown="1586">
#  Tomorrow 20:30
#  </span>,
#  <span class="arrow"></span>,
#  <span class="overlay">
#  <span class="box"></span>
#  <span class="message"></span>
#  </span>,
#  <span class="box"></span>,
#  <span class="message"></span>,
#  <span class="home-team-name" title="Defensa y Justicia">Defensa y Justicia</span>,
#  <span class="score"><span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span></span>,
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span>,
#  <span class="separator">-</span>,
#  <span class="away-team-name" title="Flamengo">Flamengo</span>,
#  <span class="status">
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="1586">
#  Tomorrow 20:30
#  </span> </span> </span>,
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="1586">
#  Tomorrow 20:30
#  </span> </span>,
#  <span class="date ui-countdown" data-countdown="1586">
#  Tomorrow 20:30
#  </span>,
#  <span class="arrow"></span>,
#  <span class="overlay">
#  <span class="box"></span>
#  <span class="message"></span>
#  </span>,
#  <span class="box"></span>,
#  <span class="message"></span>,
#  <span class="home-team-name" title="Olimpia">Olimpia</span>,
#  <span class="score"><span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span></span>,
#  <span class="ui-no-score inplaynow-score score-template-default">
#  <span class="separator">-</span> </span>,
#  <span class="separator">-</span>,
#  <span class="away-team-name" title="Internacional">Internacional</span>,
#  <span class="status">
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="3026">
#  15 Jul 21
#  </span> </span> </span>,
#  <span class="ui-no-score">
#  <span class="date ui-countdown" data-countdown="3026">
#  15 Jul 21
#  </span> </span>,
#  <span class="date ui-countdown" data-countdown="3026">
#  15 Jul 21
#  </span>,
#  <span class="arrow"></span>,
#  <span class="back-button-icon"></span>,
#  <span class="back-button-label">
#  View CONMEBOL Copa Libertadores coupon
#  </span>,
#  <span class="selected-label" data-choose="">More <span class="counter invisible">(10)</span></span>,
#  <span class="counter invisible">(10)</span>,
#  <span class="arrow"></span>,
#  <span class="ui-new-label">NEW</span>,
#  <span class="ui-new-label">NEW</span>,
#  <span class="ui-icon-wrap arrow"><span class="svg-icon-arrow-right-white ui-icon"></span></span>,
#  <span class="svg-icon-arrow-right-white ui-icon"></span>,
#  <span class="title">Match Results Markets</span>,
#  <span class="indicators">
#  <span class="ui-cashout-indicator ui-indicator"><span class="ui-icon"></span></span>
#  </span>,
#  <span class="ui-cashout-indicator ui-indicator"><span class="ui-icon"></span></span>,
#  <span class="ui-icon"></span>,
#  <span class="runner-label">Cerro Porteno</span>,
#  <span class="runner-label">The Draw</span>,
#  <span class="runner-label">Fluminense</span>,
#  <span class="inplay-indicator going-inplay-icon" title="Will Go In-Play">Will Go In-Play</span>,
#  <span class="market-name">Match Odds (90 Min Only)</span>,
#  <span class=" ui-runner-price ui-924_267275689-335852 ui-display-decimal-price ">
#  2.88
#  </span>,
#  <span class=" ui-runner-price ui-924_267275689-58805 ui-display-decimal-price ">
#  2.8
#  </span>,
#  <span class=" ui-runner-price ui-924_267275689-198133 ui-display-decimal-price ">
#  2.55
#  </span>,
#  <span class="market-name">To Qualify (Incl ET and Pen)</span>,
#  <span class=" ui-runner-price ui-924_269946190-335852 ui-display-decimal-price ">
#  2.25
#  </span>,
#  <span class=" ui-runner-price ui-924_269946190-58805 ui-display-decimal-price ">
#
#  </span>,
#  <span class=" ui-runner-price ui-924_269946190-198133 ui-display-decimal-price ">
#  1.57
#  </span>,
#  <span class="ui-icon-wrap arrow"><span class="svg-icon-arrow-right-white ui-icon"></span></span>,
#  <span class="svg-icon-arrow-right-white ui-icon"></span>,
#  <span class="title">Correct Score</span>,
#  <span class="indicators">
#  <span class="ui-cashout-indicator ui-indicator"><span class="ui-icon"></span></span>
#  <span class="inplay-indicator going-inplay-icon ui-indicator" title="Will Go In-Play">Will Go In-Play</span>
#  <span class="inplay-indicator is-inplay-icon ui-indicator" title="In-Play">In-Play</span>
#  </span>,
#  <span class="ui-cashout-indicator ui-indicator"><span class="ui-icon"></span></span>,
#  <span class="ui-icon"></span>,
#  <span class="inplay-indicator going-inplay-icon ui-indicator" title="Will Go In-Play">Will Go In-Play</span>,
#  <span class="inplay-indicator is-inplay-icon ui-indicator" title="In-Play">In-Play</span>,
#  <span class="cs-col">Cerro Porteno to win</span>,
#  <span class="cs-col">Draw</span>,
#  <span class="cs-col">Fluminense to win</span>,
#  <span class="runner-name">1 - 0</span>,
#  <span class=" ui-runner-price ui-924_269431385-2 ui-display-decimal-price ">
#  6.5
#  </span>,
#  <span class="runner-name">2 - 0</span>,
#  <span class=" ui-runner-price ui-924_269431385-5 ui-display-decimal-price ">
#  12.0
#  </span>,
#  <span class="runner-name">2 - 1</span>,
#  <span class=" ui-runner-price ui-924_269431385-6 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class="runner-name">3 - 0</span>,
#  <span class=" ui-runner-price ui-924_269431385-10 ui-display-decimal-price ">
#  34.0
#  </span>,
#  <span class="runner-name">3 - 1</span>,
#  <span class=" ui-runner-price ui-924_269431385-11 ui-display-decimal-price ">
#  31.0
#  </span>,
#  <span class="runner-name">3 - 2</span>,
#  <span class=" ui-runner-price ui-924_269431385-12 ui-display-decimal-price ">
#  61.0
#  </span>,
#  <span class="runner-name">4-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458250 ui-display-decimal-price ">
#  126.0
#  </span>,
#  <span class="runner-name">4-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458251 ui-display-decimal-price ">
#  101.0
#  </span>,
#  <span class="runner-name">4-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458252 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">4-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-7573223 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458253 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458254 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458255 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781077 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781071 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458256 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458257 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458258 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781072 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-10860274 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-10947153 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458259 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458260 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458261 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671503 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-10947151 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">8-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671540 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">8-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671686 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">8-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671536 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">8-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-11132461 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">9-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671543 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">9-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671688 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">9-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-11132456 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">10-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671539 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">10-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-10860272 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">11-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-8903845 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0 - 0</span>,
#  <span class=" ui-runner-price ui-924_269431385-1 ui-display-decimal-price ">
#  5.5
#  </span>,
#  <span class="runner-name">1 - 1</span>,
#  <span class=" ui-runner-price ui-924_269431385-3 ui-display-decimal-price ">
#  5.5
#  </span>,
#  <span class="runner-name">2 - 2</span>,
#  <span class=" ui-runner-price ui-924_269431385-7 ui-display-decimal-price ">
#  19.0
#  </span>,
#  <span class="runner-name">3 - 3</span>,
#  <span class=" ui-runner-price ui-924_269431385-13 ui-display-decimal-price ">
#  151.0
#  </span>,
#  <span class="runner-name">4-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-7573222 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781073 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0 - 1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4 ui-display-decimal-price ">
#  6.0
#  </span>,
#  <span class="runner-name">0 - 2</span>,
#  <span class=" ui-runner-price ui-924_269431385-9 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class="runner-name">1 - 2</span>,
#  <span class=" ui-runner-price ui-924_269431385-8 ui-display-decimal-price ">
#  10.0
#  </span>,
#  <span class="runner-name">0 - 3</span>,
#  <span class=" ui-runner-price ui-924_269431385-16 ui-display-decimal-price ">
#  26.0
#  </span>,
#  <span class="runner-name">1 - 3</span>,
#  <span class=" ui-runner-price ui-924_269431385-15 ui-display-decimal-price ">
#  31.0
#  </span>,
#  <span class="runner-name">2 - 3</span>,
#  <span class=" ui-runner-price ui-924_269431385-14 ui-display-decimal-price ">
#  56.0
#  </span>,
#  <span class="runner-name">0-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-4744055 ui-display-decimal-price ">
#  101.0
#  </span>,
#  <span class="runner-name">1-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781081 ui-display-decimal-price ">
#  101.0
#  </span>,
#  <span class="runner-name">2-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781075 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-1308794 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-4744056 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781074 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781076 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665090 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">4-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-1266441 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781080 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781079 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781070 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671537 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">4-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665093 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-10947152 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665123 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781078 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671542 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671545 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">4-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833523 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-8</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665229 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-8</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671541 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-8</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671538 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-8</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833527 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-9</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671544 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-9</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665987 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-9</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833521 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-10</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665230 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-10</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833526 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-11</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833528 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1 - 0</span>,
#  <span class=" ui-runner-price ui-924_269431385-2 ui-display-decimal-price ">
#  6.5
#  </span>,
#  <span class="runner-name">2 - 0</span>,
#  <span class=" ui-runner-price ui-924_269431385-5 ui-display-decimal-price ">
#  12.0
#  </span>,
#  <span class="runner-name">2 - 1</span>,
#  <span class=" ui-runner-price ui-924_269431385-6 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class="runner-name">3 - 0</span>,
#  <span class=" ui-runner-price ui-924_269431385-10 ui-display-decimal-price ">
#  34.0
#  </span>,
#  <span class="runner-name">3 - 1</span>,
#  <span class=" ui-runner-price ui-924_269431385-11 ui-display-decimal-price ">
#  31.0
#  </span>,
#  <span class="runner-name">3 - 2</span>,
#  <span class=" ui-runner-price ui-924_269431385-12 ui-display-decimal-price ">
#  61.0
#  </span>,
#  <span class="runner-name">4-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458250 ui-display-decimal-price ">
#  126.0
#  </span>,
#  <span class="runner-name">4-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458251 ui-display-decimal-price ">
#  101.0
#  </span>,
#  <span class="runner-name">4-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458252 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">4-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-7573223 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458253 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458254 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458255 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781077 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781071 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458256 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458257 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458258 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781072 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-10860274 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">6-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-10947153 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458259 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458260 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-4458261 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671503 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">7-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-10947151 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">8-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671540 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">8-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671686 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">8-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671536 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">8-3</span>,
#  <span class=" ui-runner-price ui-924_269431385-11132461 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">9-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671543 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">9-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671688 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">9-2</span>,
#  <span class=" ui-runner-price ui-924_269431385-11132456 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">10-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671539 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">10-1</span>,
#  <span class=" ui-runner-price ui-924_269431385-10860272 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">11-0</span>,
#  <span class=" ui-runner-price ui-924_269431385-8903845 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0 - 0</span>,
#  <span class=" ui-runner-price ui-924_269431385-1 ui-display-decimal-price ">
#  5.5
#  </span>,
#  <span class="runner-name">1 - 1</span>,
#  <span class=" ui-runner-price ui-924_269431385-3 ui-display-decimal-price ">
#  5.5
#  </span>,
#  <span class="runner-name">2 - 2</span>,
#  <span class=" ui-runner-price ui-924_269431385-7 ui-display-decimal-price ">
#  19.0
#  </span>,
#  <span class="runner-name">3 - 3</span>,
#  <span class=" ui-runner-price ui-924_269431385-13 ui-display-decimal-price ">
#  151.0
#  </span>,
#  <span class="runner-name">4-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-7573222 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781073 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0 - 1</span>,
#  <span class=" ui-runner-price ui-924_269431385-4 ui-display-decimal-price ">
#  6.0
#  </span>,
#  <span class="runner-name">0 - 2</span>,
#  <span class=" ui-runner-price ui-924_269431385-9 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class="runner-name">1 - 2</span>,
#  <span class=" ui-runner-price ui-924_269431385-8 ui-display-decimal-price ">
#  10.0
#  </span>,
#  <span class="runner-name">0 - 3</span>,
#  <span class=" ui-runner-price ui-924_269431385-16 ui-display-decimal-price ">
#  26.0
#  </span>,
#  <span class="runner-name">1 - 3</span>,
#  <span class=" ui-runner-price ui-924_269431385-15 ui-display-decimal-price ">
#  31.0
#  </span>,
#  <span class="runner-name">2 - 3</span>,
#  <span class=" ui-runner-price ui-924_269431385-14 ui-display-decimal-price ">
#  56.0
#  </span>,
#  <span class="runner-name">0-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-4744055 ui-display-decimal-price ">
#  101.0
#  </span>,
#  <span class="runner-name">1-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781081 ui-display-decimal-price ">
#  101.0
#  </span>,
#  <span class="runner-name">2-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781075 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-4</span>,
#  <span class=" ui-runner-price ui-924_269431385-1308794 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-4744056 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781074 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781076 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665090 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">4-5</span>,
#  <span class=" ui-runner-price ui-924_269431385-1266441 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781080 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781079 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781070 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671537 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">4-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665093 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">5-6</span>,
#  <span class=" ui-runner-price ui-924_269431385-10947152 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665123 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-7781078 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671542 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671545 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">4-7</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833523 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-8</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665229 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-8</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671541 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-8</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671538 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">3-8</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833527 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-9</span>,
#  <span class=" ui-runner-price ui-924_269431385-7671544 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-9</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665987 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">2-9</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833521 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-10</span>,
#  <span class=" ui-runner-price ui-924_269431385-7665230 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">1-10</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833526 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="runner-name">0-11</span>,
#  <span class=" ui-runner-price ui-924_269431385-10833528 ui-display-decimal-price ">
#  201.0
#  </span>,
#  <span class="show-more-icon"></span>,
#  <span class="ui-icon-wrap arrow"><span class="svg-icon-arrow-right-white ui-icon"></span></span>,
#  <span class="svg-icon-arrow-right-white ui-icon"></span>,
#  <span class="title">#OddsOnThat - Featured</span>,
#  <span class="indicators">
#  <span class="ui-cashout-indicator ui-indicator"><span class="ui-icon"></span></span>
#  </span>,
#  <span class="ui-cashout-indicator ui-indicator"><span class="ui-icon"></span></span>,
#  <span class="ui-icon"></span>,
#  <span class="runner-name" title="Each Team to have 3+ Cards">Each Team to have 3+ Cards</span>,
#  <span class=" ui-runner-price ui-924_270013889-25894717 ui-display-decimal-price ">
#  2.38
#  </span>,
#  <span class="runner-name" title="Over 2.5 Goals; Over 2.5 Cards &amp; Over 8.5 Corners">Over 2.5 Goals; Over 2.5 Cards &amp; Over 8.5 Corners</span>,
#  <span class=" ui-runner-price ui-924_270013889-25482275 ui-display-decimal-price ">
#  4.5
#  </span>,
#  <span class="runner-name" title="Each team to have 2 or more corners in each half">Each team to have 2 or more corners in each half</span>,
#  <span class=" ui-runner-price ui-924_270013889-25894711 ui-display-decimal-price ">
#  5.0
#  </span>,
#  <span class="runner-name" title="Cerro Porteno Scores 2+ Goals &amp; 6+ Cerro Porteno Corners">Cerro Porteno Scores 2+ Goals &amp; 6+ Cerro Porteno Corners</span>,
#  <span class=" ui-runner-price ui-924_270013889-40179177 ui-display-decimal-price ">
#  7.0
#  </span>,
#  <span class="runner-name" title="Over 1.5 second half Goals &amp; over 5.5 second half Corners">Over 1.5 second half Goals &amp; over 5.5 second half Corners</span>,
#  <span class=" ui-runner-price ui-924_270013889-25789928 ui-display-decimal-price ">
#  7.0
#  </span>,
#  <span class="runner-name" title="Over 2.5 goals; over 5.5 cards &amp; over 8.5 corners">Over 2.5 goals; over 5.5 cards &amp; over 8.5 corners</span>,
#  <span class=" ui-runner-price ui-924_270013889-25789844 ui-display-decimal-price ">
#  7.5
#  </span>,
#  <span class="runner-name" title="Each team to get 6 or more Corners">Each team to get 6 or more Corners</span>,
#  <span class=" ui-runner-price ui-924_270013889-25894732 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class="runner-name" title="Cerro Porteno to Win; Cerro Porteno Most Corners &amp; Fluminense Most Cards">Cerro Porteno to Win; Cerro Porteno Most Corners &amp; Fluminense Most Cards</span>,
#  <span class=" ui-runner-price ui-924_270013889-40179176 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class="runner-name" title="Over 3.5 goals; over 3.5 cards &amp; over 8.5 corners">Over 3.5 goals; over 3.5 cards &amp; over 8.5 corners</span>,
#  <span class=" ui-runner-price ui-924_270013889-25789899 ui-display-decimal-price ">
#  9.5
#  </span>,
#  <span class="runner-name" title="Cerro Porteno to Score 2+ Goals; Cerro Porteno 6+ Corners &amp; Fluminense 3+ Cards">Cerro Porteno to Score 2+ Goals; Cerro Porteno 6+ Corners &amp; Fluminense 3+ Cards</span>,
#  <span class=" ui-runner-price ui-924_270013889-40179182 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class="runner-name" title="Over 3.5 goals; over 4.5 cards &amp; over 8.5 corners">Over 3.5 goals; over 4.5 cards &amp; over 8.5 corners</span>,
#  <span class=" ui-runner-price ui-924_270013889-25789906 ui-display-decimal-price ">
# ...
#  <span class=" ui-runner-price ui-924_270013887-25894739 ui-display-decimal-price ">
#  2.25
#  </span>,
#  <span class="runner-name" title="Cerro Porteno Scores 1+ Goals &amp; 5+ Cerro Porteno Corners">Cerro Porteno Scores 1+ Goals &amp; 5+ Cerro Porteno Corners</span>,
#  <span class=" ui-runner-price ui-924_270013887-40179200 ui-display-decimal-price ">
#  2.38
#  </span>,
#  <span class="runner-name" title="Cerro Porteno to Score 1+ Goals; Cerro Porteno 5+ Corners &amp; Fluminense 2+ Cards">Cerro Porteno to Score 1+ Goals; Cerro Porteno 5+ Corners &amp; Fluminense 2+ Cards</span>,
#  <span class=" ui-runner-price ui-924_270013887-40179202 ui-display-decimal-price ">
#  2.88
#  </span>,
#  <span class="runner-name" title="Over 2.5 Match Goals; Over 2.5 Cards &amp; Over 5.5 Corners">Over 2.5 Match Goals; Over 2.5 Cards &amp; Over 5.5 Corners</span>,
#  <span class=" ui-runner-price ui-924_270013887-25497491 ui-display-decimal-price ">
#  2.88
#  </span>,
#  <span class="runner-name" title="Each Team to have 1+ Cards in each half">Each Team to have 1+ Cards in each half</span>,
#  <span class=" ui-runner-price ui-924_270013887-25894735 ui-display-decimal-price ">
#  2.88
#  </span>,
#  <span class="runner-name" title="Over 2.5 Match Goals; Over 3.5 Cards &amp; Over 5.5 Corners">Over 2.5 Match Goals; Over 3.5 Cards &amp; Over 5.5 Corners</span>,
#  <span class=" ui-runner-price ui-924_270013887-25497493 ui-display-decimal-price ">
#  3.25
#  </span>,
#  <span class="runner-name" title="Fluminense Scores 1+ Goals &amp; 5+ Fluminense Corners">Fluminense Scores 1+ Goals &amp; 5+ Fluminense Corners</span>,
#  <span class=" ui-runner-price ui-924_270013887-32710040 ui-display-decimal-price ">
#  3.5
#  </span>,
#  <span class="runner-name" title="Fluminense Win 1-0; 2-0 or 2-1">Fluminense Win 1-0; 2-0 or 2-1</span>,
#  <span class=" ui-runner-price ui-924_270013887-32710039 ui-display-decimal-price ">
#  3.5
#  </span>,
#  <span class="runner-name" title="Fluminense Win 1-0; 2-0 or 3-0">Fluminense Win 1-0; 2-0 or 3-0</span>,
#  <span class=" ui-runner-price ui-924_270013887-32710063 ui-display-decimal-price ">
#  4.33
#  </span>,
#  <span class="runner-name" title="Fluminense to Score 1+ Goals; Fluminense 5+ Corners &amp; Cerro Porteno 2+ Cards">Fluminense to Score 1+ Goals; Fluminense 5+ Corners &amp; Cerro Porteno 2+ Cards</span>,
#  <span class=" ui-runner-price ui-924_270013887-40179205 ui-display-decimal-price ">
#  4.5
#  </span>,
#  <span class="runner-name" title="1+ Goals In Each Half; 4+ Corners In Each Half &amp; 1+ Cards In Each Half">1+ Goals In Each Half; 4+ Corners In Each Half &amp; 1+ Cards In Each Half</span>,
#  <span class=" ui-runner-price ui-924_270013887-25894705 ui-display-decimal-price ">
#  5.0
#  </span>,
#  <span class="runner-name" title="Over 2.5 goals; over 3.5 cards &amp; over 8.5 corners">Over 2.5 goals; over 3.5 cards &amp; over 8.5 corners</span>,
#  <span class=" ui-runner-price ui-924_270013887-25789895 ui-display-decimal-price ">
#  5.0
#  </span>,
#  <span class="runner-name" title="Over 2.5 goals; over 4.5 cards &amp; over 8.5 corners">Over 2.5 goals; over 4.5 cards &amp; over 8.5 corners</span>,
#  <span class=" ui-runner-price ui-924_270013887-25789901 ui-display-decimal-price ">
#  6.0
#  </span>,
#  <span class="runner-name" title="Cerro Porteno to Score 2+ Goals; Cerro Porteno 5+ Corners &amp; Fluminense 2+ Cards">Cerro Porteno to Score 2+ Goals; Cerro Porteno 5+ Corners &amp; Fluminense 2+ Cards</span>,
#  <span class=" ui-runner-price ui-924_270013887-40179204 ui-display-decimal-price ">
#  6.5
#  </span>,
#  <span class="runner-name" title="Cerro Porteno Penalty Awarded &amp; Cerro Porteno Over 4.5 Corners">Cerro Porteno Penalty Awarded &amp; Cerro Porteno Over 4.5 Corners</span>,
#  <span class=" ui-runner-price ui-924_270013887-40179201 ui-display-decimal-price ">
#  7.0
#  </span>,
#  <span class="runner-name" title="Fluminense Win 2-1 or 3-1">Fluminense Win 2-1 or 3-1</span>,
#  <span class=" ui-runner-price ui-924_270013887-32710062 ui-display-decimal-price ">
#  7.5
#  </span>,
#  <span class="runner-name" title="Cerro Porteno Win 2-0; 3-0 or 4-0">Cerro Porteno Win 2-0; 3-0 or 4-0</span>,
#  <span class=" ui-runner-price ui-924_270013887-40179199 ui-display-decimal-price ">
#  7.5
#  </span>,
#  <span class="runner-name" title="Fluminense Scores First in Each Half">Fluminense Scores First in Each Half</span>,
#  <span class=" ui-runner-price ui-924_270013887-32710064 ui-display-decimal-price ">
#  7.5
#  </span>,
#  <span class="runner-name" title="Neither team to get 4 or more Corners">Neither team to get 4 or more Corners</span>,
#  <span class=" ui-runner-price ui-924_270013887-25894776 ui-display-decimal-price ">
#  7.5
#  </span>,
#  <span class="runner-name" title="Fluminense to Win the Match &amp; Fluminense Score Penalty">Fluminense to Win the Match &amp; Fluminense Score Penalty</span>,
#  <span class=" ui-runner-price ui-924_270013887-36939391 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class="runner-name" title="Fluminense Win 2-0 or 3-0">Fluminense Win 2-0 or 3-0</span>,
#  <span class=" ui-runner-price ui-924_270013887-32710050 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class="runner-name" title="Cerro Porteno to Score in Both Halves &amp; Cerro Porteno Over 1.5 Corners Each Half">Cerro Porteno to Score in Both Halves &amp; Cerro Porteno Over 1.5 Corners Each Half</span>,
#  <span class=" ui-runner-price ui-924_270013887-40179203 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class="ui-icon-wrap arrow"><span class="svg-icon-arrow-right-white ui-icon"></span></span>,
#  <span class="svg-icon-arrow-right-white ui-icon"></span>,
#  <span class="title">Goalscorer Markets</span>,
#  <span class="indicators">
#  <span class="ui-cashout-indicator ui-indicator"><span class="ui-icon"></span></span>
#  <span class="inplay-indicator going-inplay-icon ui-indicator" title="Will Go In-Play">Will Go In-Play</span>
#  <span class="inplay-indicator is-inplay-icon ui-indicator" title="In-Play">In-Play</span>
#  </span>,
#  <span class="ui-cashout-indicator ui-indicator"><span class="ui-icon"></span></span>,
#  <span class="ui-icon"></span>,
#  <span class="inplay-indicator going-inplay-icon ui-indicator" title="Will Go In-Play">Will Go In-Play</span>,
#  <span class="inplay-indicator is-inplay-icon ui-indicator" title="In-Play">In-Play</span>,
#  <span class="market-name ui-924_269998638">
#  First Goalscorer
#  </span>,
#  <span class="market-name ui-924_269998636">
#  Last Goalscorer
#  </span>,
#  <span class="market-name ui-924_269998639">
#  Anytime Goalscorer
#  </span>,
#  <span class="market-name ui-924_269998632">
#  To Score 2 Goals or more
#  </span>,
#  <span class="market-name ui-924_269998622">
#  To Score a Hat-trick?
#  </span>,
#  <span class="market-name ui-924_269998638">
#  First Goalscorer
#  </span>,
#  <span class="market-name ui-924_269998636">
#  Last Goalscorer
#  </span>,
#  <span class="market-name ui-924_269998639">
#  Anytime Goalscorer
#  </span>,
#  <span class="market-name ui-924_269998632">
#  To Score 2 Goals or more
#  </span>,
#  <span class="market-name ui-924_269998622">
#  To Score a Hat-trick?
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-16082847 ui-display-decimal-price ">
#  5.5
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-7393690 ui-display-decimal-price ">
#  7.5
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177198 ui-display-decimal-price ">
#  8.5
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-15434252 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-279220 ui-display-decimal-price ">
#  8.5
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-4145274 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-4396192 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177203 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177197 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177196 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40108534 ui-display-decimal-price ">
#  10.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-28743852 ui-display-decimal-price ">
#  10.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-37028783 ui-display-decimal-price ">
#  10.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177201 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177199 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177195 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-23977006 ui-display-decimal-price ">
#  12.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-39594002 ui-display-decimal-price ">
#  13.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-39590388 ui-display-decimal-price ">
#  13.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-7966121 ui-display-decimal-price ">
#  13.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-9570066 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-24188752 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-36335317 ui-display-decimal-price ">
#  14.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-26092634 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-6516843 ui-display-decimal-price ">
#  13.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177194 ui-display-decimal-price ">
#  14.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-20267458 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177190 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-7966081 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-1365999 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177188 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-15434256 ui-display-decimal-price ">
#  18.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-34725061 ui-display-decimal-price ">
#  17.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-1478388 ui-display-decimal-price ">
#  18.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-11215553 ui-display-decimal-price ">
#  19.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-18311968 ui-display-decimal-price ">
#  21.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-36335314 ui-display-decimal-price ">
#  26.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-15223787 ui-display-decimal-price ">
#  31.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-14337678 ui-display-decimal-price ">
#  36.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-7966394 ui-display-decimal-price ">
#  41.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-23461582 ui-display-decimal-price ">
#  41.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177189 ui-display-decimal-price ">
#  41.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-9334675 ui-display-decimal-price ">
#  41.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177200 ui-display-decimal-price ">
#  46.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-39589115 ui-display-decimal-price ">
#  51.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177191 ui-display-decimal-price ">
#  56.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-2469643 ui-display-decimal-price ">
#  61.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-15241261 ui-display-decimal-price ">
#  61.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-5703108 ui-display-decimal-price ">
#  61.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-36317665 ui-display-decimal-price ">
#  61.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177193 ui-display-decimal-price ">
#  61.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-12789229 ui-display-decimal-price ">
#  76.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-40177192 ui-display-decimal-price ">
#  81.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-37028788 ui-display-decimal-price ">
#  81.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998638-39673718 ui-display-decimal-price ">
#  81.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-16082847 ui-display-decimal-price ">
#  5.5
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-7393690 ui-display-decimal-price ">
#  7.5
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177198 ui-display-decimal-price ">
#  8.5
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-15434252 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-279220 ui-display-decimal-price ">
#  8.5
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-4145274 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-4396192 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177203 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177197 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177196 ui-display-decimal-price ">
#  9.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40108534 ui-display-decimal-price ">
#  10.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-28743852 ui-display-decimal-price ">
#  10.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-37028783 ui-display-decimal-price ">
#  10.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177201 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177199 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177195 ui-display-decimal-price ">
#  11.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-23977006 ui-display-decimal-price ">
#  12.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-39594002 ui-display-decimal-price ">
#  13.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-39590388 ui-display-decimal-price ">
#  13.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-7966121 ui-display-decimal-price ">
#  13.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-9570066 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-24188752 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-36335317 ui-display-decimal-price ">
#  14.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-26092634 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-6516843 ui-display-decimal-price ">
#  13.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177194 ui-display-decimal-price ">
#  14.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-20267458 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177190 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-7966081 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-1365999 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-40177188 ui-display-decimal-price ">
#  15.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-15434256 ui-display-decimal-price ">
#  18.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-34725061 ui-display-decimal-price ">
#  17.0
#  </span>,
#  <span class=" ui-runner-price ui-924_269998636-1478388 ui-display-decimal-price ">
#  18.0
#  </span>,
#  ...]

# %%
option = Options()

option.add_argument("--disable-infobars")
option.add_argument("start-maximized")
option.add_argument("--disable-extensions")

# Pass the argument 1 to allow and 2 to block
option.add_experimental_option("prefs", { 
    "profile.default_content_setting_values.notifications": 1 
})

navegador = webdriver.Chrome(executable_path='C:\\Users\\johnk\\AppData\\Local\\Programs\\Python\\Python39\\chromedriver.exe')
        
navegador.get(url)

sleep(0.5)
navegador.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]').click()

soup = BeautifulSoup(navegador.page_source)

navegador.quit()
soup.find_all("div")
# Out:
# ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-vencntr"><input aria-checked="true" checked="" id="select-all-vendor-groups-handler" type="checkbox"/> <label for="select-all-vendor-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-licntr"><input aria-checked="true" checked="" id="select-all-vendor-leg-handler" type="checkbox"/> <label for="select-all-vendor-leg-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div></div><ul id="ot-ven-lst"></ul></div></div>,
#  <div class="ot-sdk-column"><div id="ot-sel-blk"><div class="ot-sel-all"><div class="ot-sel-all-hdr"><span class="ot-consent-hdr">Consent</span> <span class="ot-li-hdr">Leg.Interest</span></div><div class="ot-sel-all-chkbox"><div class="ot-chkbox" id="ot-selall-hostcntr"><input aria-checked="false" id="select-all-hosts-groups-handler" type="checkbox"/> <label for="select-all-hosts-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-vencntr"><input aria-checked="true" checked="" id="select-all-vendor-groups-handler" type="checkbox"/> <label for="select-all-vendor-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-licntr"><input aria-checked="true" checked="" id="select-all-vendor-leg-handler" type="checkbox"/> <label for="select-all-vendor-leg-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div></div><ul id="ot-ven-lst"></ul></div>,
#  <div id="ot-sel-blk"><div class="ot-sel-all"><div class="ot-sel-all-hdr"><span class="ot-consent-hdr">Consent</span> <span class="ot-li-hdr">Leg.Interest</span></div><div class="ot-sel-all-chkbox"><div class="ot-chkbox" id="ot-selall-hostcntr"><input aria-checked="false" id="select-all-hosts-groups-handler" type="checkbox"/> <label for="select-all-hosts-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-vencntr"><input aria-checked="true" checked="" id="select-all-vendor-groups-handler" type="checkbox"/> <label for="select-all-vendor-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-licntr"><input aria-checked="true" checked="" id="select-all-vendor-leg-handler" type="checkbox"/> <label for="select-all-vendor-leg-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div></div>,
#  <div class="ot-sel-all"><div class="ot-sel-all-hdr"><span class="ot-consent-hdr">Consent</span> <span class="ot-li-hdr">Leg.Interest</span></div><div class="ot-sel-all-chkbox"><div class="ot-chkbox" id="ot-selall-hostcntr"><input aria-checked="false" id="select-all-hosts-groups-handler" type="checkbox"/> <label for="select-all-hosts-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-vencntr"><input aria-checked="true" checked="" id="select-all-vendor-groups-handler" type="checkbox"/> <label for="select-all-vendor-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-licntr"><input aria-checked="true" checked="" id="select-all-vendor-leg-handler" type="checkbox"/> <label for="select-all-vendor-leg-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div>,
#  <div class="ot-sel-all-hdr"><span class="ot-consent-hdr">Consent</span> <span class="ot-li-hdr">Leg.Interest</span></div>,
#  <div class="ot-sel-all-chkbox"><div class="ot-chkbox" id="ot-selall-hostcntr"><input aria-checked="false" id="select-all-hosts-groups-handler" type="checkbox"/> <label for="select-all-hosts-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-vencntr"><input aria-checked="true" checked="" id="select-all-vendor-groups-handler" type="checkbox"/> <label for="select-all-vendor-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div><div class="ot-chkbox" id="ot-selall-licntr"><input aria-checked="true" checked="" id="select-all-vendor-leg-handler" type="checkbox"/> <label for="select-all-vendor-leg-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div>,
#  <div class="ot-chkbox" id="ot-selall-hostcntr"><input aria-checked="false" id="select-all-hosts-groups-handler" type="checkbox"/> <label for="select-all-hosts-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div>,
#  <div class="ot-chkbox" id="ot-selall-vencntr"><input aria-checked="true" checked="" id="select-all-vendor-groups-handler" type="checkbox"/> <label for="select-all-vendor-groups-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div>,
#  <div class="ot-chkbox" id="ot-selall-licntr"><input aria-checked="true" checked="" id="select-all-vendor-leg-handler" type="checkbox"/> <label for="select-all-vendor-leg-handler"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div>,
#  <div id="ot-anchor"></div>,
#  <div id="ot-fltr-cnt"><button id="clear-filters-handler">Clear</button><div class="ot-fltr-scrlcnt ot-pc-scrollbar"><div class="ot-fltr-opts"><div class="ot-fltr-opt"><div class="ot-chkbox"><input aria-checked="false" class="category-filter-handler" id="chkbox-id" type="checkbox"/> <label for="chkbox-id"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div><div class="ot-fltr-btns"><button id="filter-apply-handler">Apply</button> <button id="filter-cancel-handler">Cancel</button></div></div></div>,
#  <div class="ot-fltr-scrlcnt ot-pc-scrollbar"><div class="ot-fltr-opts"><div class="ot-fltr-opt"><div class="ot-chkbox"><input aria-checked="false" class="category-filter-handler" id="chkbox-id" type="checkbox"/> <label for="chkbox-id"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div><div class="ot-fltr-btns"><button id="filter-apply-handler">Apply</button> <button id="filter-cancel-handler">Cancel</button></div></div>,
#  <div class="ot-fltr-opts"><div class="ot-fltr-opt"><div class="ot-chkbox"><input aria-checked="false" class="category-filter-handler" id="chkbox-id" type="checkbox"/> <label for="chkbox-id"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div></div>,
#  <div class="ot-fltr-opt"><div class="ot-chkbox"><input aria-checked="false" class="category-filter-handler" id="chkbox-id" type="checkbox"/> <label for="chkbox-id"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div></div>,
#  <div class="ot-chkbox"><input aria-checked="false" class="category-filter-handler" id="chkbox-id" type="checkbox"/> <label for="chkbox-id"><span class="ot-label-txt">checkbox label</span></label> <span class="ot-label-status">label</span></div>,
#  <div class="ot-fltr-btns"><button id="filter-apply-handler">Apply</button> <button id="filter-cancel-handler">Cancel</button></div>,
#  <div class="ot-pc-footer"><div class="ot-btn-container"><button class="save-preference-btn-handler onetrust-close-btn-handler">Confirm My Choices</button><div class="ot-btn-subcntr"><button class="ot-pc-refuse-all-handler">Reject All</button> <button id="accept-recommended-btn-handler">Allow All</button></div></div><div class="ot-pc-footer-logo"><a aria-label="Powered by OneTrust Opens in a new Tab" href="https://www.onetrust.com/products/cookie-consent/" rel="noopener noreferrer" style='background-image: url("https://cdn.cookielaw.org/logos/static/poweredBy_ot_logo.svg")' target="_blank"></a></div></div>,
#  <div class="ot-btn-container"><button class="save-preference-btn-handler onetrust-close-btn-handler">Confirm My Choices</button><div class="ot-btn-subcntr"><button class="ot-pc-refuse-all-handler">Reject All</button> <button id="accept-recommended-btn-handler">Allow All</button></div></div>,
#  <div class="ot-btn-subcntr"><button class="ot-pc-refuse-all-handler">Reject All</button> <button id="accept-recommended-btn-handler">Allow All</button></div>,
#  <div class="ot-pc-footer-logo"><a aria-label="Powered by OneTrust Opens in a new Tab" href="https://www.onetrust.com/products/cookie-consent/" rel="noopener noreferrer" style='background-image: url("https://cdn.cookielaw.org/logos/static/poweredBy_ot_logo.svg")' target="_blank"></a></div>,
#  <div class="otFlat ot-iab-2 bottom vertical-align-content ot-buttons-fw" id="onetrust-banner-sdk" style="bottom: 0px" tabindex="0"><div aria-describedby="onetrust-policy-text" aria-labelledby="onetrust-policy-title" role="dialog"><div class="ot-sdk-container"><div class="ot-sdk-row"><div class="ot-sdk-columns ot-sdk-nine" id="onetrust-group-container"><div class="banner_logo"></div><div id="onetrust-policy"><h3 id="onetrust-policy-title">We Care About Your Privacy</h3><p id="onetrust-policy-text">We and our partners store and/or access information on a device, such as unique IDs in cookies to process personal data. You may accept or manage your choices by clicking below, including your right to object where legitimate interest is used, or at any time in the privacy policy page. These choices will be signaled to our partners and will not affect browsing data.</p><div class="ot-dpd-container"><h3 class="ot-dpd-title">We and our partners process data to provide:</h3><div class="ot-dpd-content"><p class="ot-dpd-desc">Use precise geolocation data. Actively scan device characteristics for identification. Store and/or access information on a device. Personalised ads and content, ad and content measurement, audience insights and product development. <button class="ot-link-btn onetrust-vendors-list-handler">
#                  List of Partners (vendors)
#                  </button></p></div></div></div></div><div class="ot-sdk-three ot-sdk-columns has-reject-all-button" id="onetrust-button-group-parent"><div id="onetrust-button-group"><button id="onetrust-accept-btn-handler">I Accept</button> <button id="onetrust-reject-all-handler">Reject All</button> <button id="onetrust-pc-btn-handler">Show Purposes</button></div></div></div></div><!-- Close Button --><div id="onetrust-close-btn-container"><button aria-label="Close" class="onetrust-close-btn-handler onetrust-close-btn-ui banner-close-button ot-close-icon"></button></div><!-- Close Button END--></div></div>,
#  <div aria-describedby="onetrust-policy-text" aria-labelledby="onetrust-policy-title" role="dialog"><div class="ot-sdk-container"><div class="ot-sdk-row"><div class="ot-sdk-columns ot-sdk-nine" id="onetrust-group-container"><div class="banner_logo"></div><div id="onetrust-policy"><h3 id="onetrust-policy-title">We Care About Your Privacy</h3><p id="onetrust-policy-text">We and our partners store and/or access information on a device, such as unique IDs in cookies to process personal data. You may accept or manage your choices by clicking below, including your right to object where legitimate interest is used, or at any time in the privacy policy page. These choices will be signaled to our partners and will not affect browsing data.</p><div class="ot-dpd-container"><h3 class="ot-dpd-title">We and our partners process data to provide:</h3><div class="ot-dpd-content"><p class="ot-dpd-desc">Use precise geolocation data. Actively scan device characteristics for identification. Store and/or access information on a device. Personalised ads and content, ad and content measurement, audience insights and product development. <button class="ot-link-btn onetrust-vendors-list-handler">
#                  List of Partners (vendors)
#                  </button></p></div></div></div></div><div class="ot-sdk-three ot-sdk-columns has-reject-all-button" id="onetrust-button-group-parent"><div id="onetrust-button-group"><button id="onetrust-accept-btn-handler">I Accept</button> <button id="onetrust-reject-all-handler">Reject All</button> <button id="onetrust-pc-btn-handler">Show Purposes</button></div></div></div></div><!-- Close Button --><div id="onetrust-close-btn-container"><button aria-label="Close" class="onetrust-close-btn-handler onetrust-close-btn-ui banner-close-button ot-close-icon"></button></div><!-- Close Button END--></div>,
#  <div class="ot-sdk-container"><div class="ot-sdk-row"><div class="ot-sdk-columns ot-sdk-nine" id="onetrust-group-container"><div class="banner_logo"></div><div id="onetrust-policy"><h3 id="onetrust-policy-title">We Care About Your Privacy</h3><p id="onetrust-policy-text">We and our partners store and/or access information on a device, such as unique IDs in cookies to process personal data. You may accept or manage your choices by clicking below, including your right to object where legitimate interest is used, or at any time in the privacy policy page. These choices will be signaled to our partners and will not affect browsing data.</p><div class="ot-dpd-container"><h3 class="ot-dpd-title">We and our partners process data to provide:</h3><div class="ot-dpd-content"><p class="ot-dpd-desc">Use precise geolocation data. Actively scan device characteristics for identification. Store and/or access information on a device. Personalised ads and content, ad and content measurement, audience insights and product development. <button class="ot-link-btn onetrust-vendors-list-handler">
#                  List of Partners (vendors)
#                  </button></p></div></div></div></div><div class="ot-sdk-three ot-sdk-columns has-reject-all-button" id="onetrust-button-group-parent"><div id="onetrust-button-group"><button id="onetrust-accept-btn-handler">I Accept</button> <button id="onetrust-reject-all-handler">Reject All</button> <button id="onetrust-pc-btn-handler">Show Purposes</button></div></div></div></div>,
#  <div class="ot-sdk-row"><div class="ot-sdk-columns ot-sdk-nine" id="onetrust-group-container"><div class="banner_logo"></div><div id="onetrust-policy"><h3 id="onetrust-policy-title">We Care About Your Privacy</h3><p id="onetrust-policy-text">We and our partners store and/or access information on a device, such as unique IDs in cookies to process personal data. You may accept or manage your choices by clicking below, including your right to object where legitimate interest is used, or at any time in the privacy policy page. These choices will be signaled to our partners and will not affect browsing data.</p><div class="ot-dpd-container"><h3 class="ot-dpd-title">We and our partners process data to provide:</h3><div class="ot-dpd-content"><p class="ot-dpd-desc">Use precise geolocation data. Actively scan device characteristics for identification. Store and/or access information on a device. Personalised ads and content, ad and content measurement, audience insights and product development. <button class="ot-link-btn onetrust-vendors-list-handler">
#                  List of Partners (vendors)
#                  </button></p></div></div></div></div><div class="ot-sdk-three ot-sdk-columns has-reject-all-button" id="onetrust-button-group-parent"><div id="onetrust-button-group"><button id="onetrust-accept-btn-handler">I Accept</button> <button id="onetrust-reject-all-handler">Reject All</button> <button id="onetrust-pc-btn-handler">Show Purposes</button></div></div></div>,
#  <div class="ot-sdk-columns ot-sdk-nine" id="onetrust-group-container"><div class="banner_logo"></div><div id="onetrust-policy"><h3 id="onetrust-policy-title">We Care About Your Privacy</h3><p id="onetrust-policy-text">We and our partners store and/or access information on a device, such as unique IDs in cookies to process personal data. You may accept or manage your choices by clicking below, including your right to object where legitimate interest is used, or at any time in the privacy policy page. These choices will be signaled to our partners and will not affect browsing data.</p><div class="ot-dpd-container"><h3 class="ot-dpd-title">We and our partners process data to provide:</h3><div class="ot-dpd-content"><p class="ot-dpd-desc">Use precise geolocation data. Actively scan device characteristics for identification. Store and/or access information on a device. Personalised ads and content, ad and content measurement, audience insights and product development. <button class="ot-link-btn onetrust-vendors-list-handler">
#                  List of Partners (vendors)
#                  </button></p></div></div></div></div>,
#  <div class="banner_logo"></div>,
#  <div id="onetrust-policy"><h3 id="onetrust-policy-title">We Care About Your Privacy</h3><p id="onetrust-policy-text">We and our partners store and/or access information on a device, such as unique IDs in cookies to process personal data. You may accept or manage your choices by clicking below, including your right to object where legitimate interest is used, or at any time in the privacy policy page. These choices will be signaled to our partners and will not affect browsing data.</p><div class="ot-dpd-container"><h3 class="ot-dpd-title">We and our partners process data to provide:</h3><div class="ot-dpd-content"><p class="ot-dpd-desc">Use precise geolocation data. Actively scan device characteristics for identification. Store and/or access information on a device. Personalised ads and content, ad and content measurement, audience insights and product development. <button class="ot-link-btn onetrust-vendors-list-handler">
#                  List of Partners (vendors)
#                  </button></p></div></div></div>,
#  <div class="ot-dpd-container"><h3 class="ot-dpd-title">We and our partners process data to provide:</h3><div class="ot-dpd-content"><p class="ot-dpd-desc">Use precise geolocation data. Actively scan device characteristics for identification. Store and/or access information on a device. Personalised ads and content, ad and content measurement, audience insights and product development. <button class="ot-link-btn onetrust-vendors-list-handler">
#                  List of Partners (vendors)
#                  </button></p></div></div>,
#  <div class="ot-dpd-content"><p class="ot-dpd-desc">Use precise geolocation data. Actively scan device characteristics for identification. Store and/or access information on a device. Personalised ads and content, ad and content measurement, audience insights and product development. <button class="ot-link-btn onetrust-vendors-list-handler">
#                  List of Partners (vendors)
#                  </button></p></div>,
#  <div class="ot-sdk-three ot-sdk-columns has-reject-all-button" id="onetrust-button-group-parent"><div id="onetrust-button-group"><button id="onetrust-accept-btn-handler">I Accept</button> <button id="onetrust-reject-all-handler">Reject All</button> <button id="onetrust-pc-btn-handler">Show Purposes</button></div></div>,
#  <div id="onetrust-button-group"><button id="onetrust-accept-btn-handler">I Accept</button> <button id="onetrust-reject-all-handler">Reject All</button> <button id="onetrust-pc-btn-handler">Show Purposes</button></div>,
#  <div id="onetrust-close-btn-container"><button aria-label="Close" class="onetrust-close-btn-handler onetrust-close-btn-ui banner-close-button ot-close-icon"></button></div>]

# %%
option = Options()

option.add_argument("--disable-infobars")
option.add_argument("start-maximized")
option.add_argument("--disable-extensions")

# Pass the argument 1 to allow and 2 to block
option.add_experimental_option("prefs", { 
    "profile.default_content_setting_values.notifications": 1 
})

navegador = webdriver.Chrome(options=option, executable_path='C:\\Users\\johnk\\AppData\\Local\\Programs\\Python\\Python39\\chromedriver.exe')
        
navegador.get(test_url)

sleep(1)

# Accept
navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div[4]/div[2]/button[1]').click()
sleep(1)
# First image
navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/main/div[1]/div/div[1]/div[3]').click()
sleep(0.5)
for i in range(200):
    try:
        img = navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div[1]/div[1]/div/img')
        src = img.get_attribute('src')
        urlretrieve(src, f'images/{i}.png')
    except:
        navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div[1]/button[2]').click()
    else:
        navegador.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div[1]/button[2]').click()
    sleep(0.1)
