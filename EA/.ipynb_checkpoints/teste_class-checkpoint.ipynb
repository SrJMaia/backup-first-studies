# %%
import MetaTrader5 as mt5
import pandas as pd
from time import sleep
import financial as fn
import data as dt
from mt5 import login_mt5
from time import sleep

# %%
results = login_mt5(login=41442678,password='0cxebqvs',server='MetaQuotes-Demo')

df = dt.get_data(0, 3000, mt5.TIMEFRAME_D1)
data = dt.pct_data(df, period=16)
data = dt.signals(data)

account_info=mt5.account_info()._asdict()

mt5.shutdown()
# Out:
# True

# %%
data[list[('EURCHF','EURGBP','EURJPY','EURNZD','EURUSD','EURAUD','EURCAD', 'GBPAUD','GBPCHF','GBPJPY','GBPCAD','GBPUSD','GBPNZD','USDCHF','USDJPY','AUDUSD','NZDUSD','USDCAD','AUDJPY','CADJPY','CHFJPY','NZDJPY','AUDCHF','CADCHF','NZDCHF','AUDNZD','NZDCAD','AUDCAD')]]
# Out:
#        EURCHF   EURGBP   EURJPY   EURNZD   EURUSD   EURAUD   EURCAD   GBPAUD  \
# 0     1.51920  0.90430  134.460  2.04740  1.47889  1.69440  1.58210  1.95006
# 1     1.51640  0.90010  133.780  2.04610  1.46886  1.69360  1.59640  1.94462
# 2     1.51550  0.91290  131.760  2.04880  1.46608  1.69610  1.60430  1.92420
# 3     1.51440  0.92050  131.080  2.03990  1.47011  1.67490  1.58590  1.90942
# 4     1.51280  0.92030  131.470  2.03820  1.46132  1.67350  1.58200  1.91362
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 2995  1.10295  0.86385  130.366  1.69135  1.18666  1.55937  1.49638  1.80312
# 2996  1.10077  0.86722  130.172  1.68785  1.19121  1.55621  1.49641  1.79383
# 2997  1.09942  0.86619  130.296  1.68429  1.18881  1.55814  1.48818  1.79397
# 2998  1.09825  0.86631  130.272  1.69387  1.19093  1.56210  1.49615  1.80124
# 2999  1.09979  0.86875  130.295  1.69260  1.19478  1.56315  1.49764  1.79910
#
# ...

# %%
data[['EURCHF','EURGBP','EURJPY','EURNZD','EURUSD','EURAUD','EURCAD',
                 'GBPAUD','GBPCHF','GBPJPY','GBPCAD','GBPUSD','GBPNZD','USDCHF',
                 'USDJPY','AUDUSD','NZDUSD','USDCAD','AUDJPY','CADJPY','CHFJPY',
                 'NZDJPY','AUDCHF','CADCHF','NZDCHF','AUDNZD','NZDCAD','AUDCAD']]
# Out:
#        EURCHF   EURGBP   EURJPY   EURNZD   EURUSD   EURAUD   EURCAD   GBPAUD  \
# 0     1.51920  0.90430  134.460  2.04740  1.47889  1.69440  1.58210  1.95006
# 1     1.51640  0.90010  133.780  2.04610  1.46886  1.69360  1.59640  1.94462
# 2     1.51550  0.91290  131.760  2.04880  1.46608  1.69610  1.60430  1.92420
# 3     1.51440  0.92050  131.080  2.03990  1.47011  1.67490  1.58590  1.90942
# 4     1.51280  0.92030  131.470  2.03820  1.46132  1.67350  1.58200  1.91362
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 2995  1.10295  0.86385  130.366  1.69135  1.18666  1.55937  1.49638  1.80312
# 2996  1.10077  0.86722  130.172  1.68785  1.19121  1.55621  1.49641  1.79383
# 2997  1.09942  0.86619  130.296  1.68429  1.18881  1.55814  1.48818  1.79397
# 2998  1.09825  0.86631  130.272  1.69387  1.19093  1.56210  1.49615  1.80124
# 2999  1.09979  0.86875  130.295  1.69260  1.19478  1.56315  1.49764  1.79910
#
# ...
