# %%
import MetaTrader5 as mt5
import pandas as pd
import financial as fn
import gui
from data import get_data
from mt5 import login_mt5
from time import sleep
from PySimpleGUI import PySimpleGUI as sg
import matplotlib.pyplot as plt

# %%
login_mt5(login=40305620,password='x8dcteyv',server='MetaQuotes-Demo')
data = get_data(start=0,end=70000)
mt5.shutdown()
# Out:
# True

# %%
data.describe()
# Out:
#                 eur           gbp           usd           jpy           chf  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      -0.000784     -0.000126      0.000090      0.001585     -0.000935
# std        0.383684      0.361307      0.316483      0.498108      0.397356
# min      -17.148246    -15.123708    -16.590220    -13.809834    -17.464443
# 25%       -0.184237     -0.191178     -0.159024     -0.230717     -0.189791
# 50%       -0.001085      0.000376      0.001747      0.008267      0.001677
# 75%        0.181675      0.191999      0.160475      0.240708      0.191014
# max        7.633533      6.560099      6.302789     17.253537      7.485596
#
#                 nzd           aud           cad
# count  70000.000000  70000.000000  70000.000000
# mean       0.000419     -0.000211      0.000645
# std        0.397892      0.380520      0.359954
# min      -14.226082    -15.190911    -16.244616
# ...

# %%
data.mean()
# Out:
# eur   -0.000784
# gbp   -0.000126
# usd    0.000090
# jpy    0.001585
# chf   -0.000935
# nzd    0.000419
# aud   -0.000211
# cad    0.000645
# dtype: float64

# %%
plt.hist(data['eur'],bins=100,range=(-2,2))
plt.figure(figsize=(30,30))
plt.grid()
plt.show()

# %%
events = fn.MY_EVENTS

# %%
events['EURUSD']
# Out:
# {'buy': True,
#  'sell': True,
#  'sell_request': 0,
#  'buy_request': 0,
#  'symbol': 'EURUSD',
#  'first_currency': 'eur',
#  'second_currency': 'usd'}

# %%
EURUSD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURUSD','first_currency':'eur','second_currency':'usd'}
EURCHF = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURCHF','first_currency':'eur','second_currency':'chf'}
EURGBP = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURGBP','first_currency':'eur','second_currency':'gbp'}
EURJPY = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURJPY','first_currency':'eur','second_currency':'jpy'}
EURNZD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURNZD','first_currency':'eur','second_currency':'nzd'}
EURAUD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURAUD','first_currency':'eur','second_currency':'aud'}
EURCAD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURCAD','first_currency':'eur','second_currency':'cad'}

GBPAUD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'GBPAUD','first_currency':'gbp','second_currency':'aud'}
GBPCHF = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'GBPCHF','first_currency':'gbp','second_currency':'chf'}
GBPJPY = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'GBPJPY','first_currency':'gbp','second_currency':'jpy'}
GBPCAD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'GBPCAD','first_currency':'gbp','second_currency':'cad'}
GBPUSD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'GBPUSD','first_currency':'gbp','second_currency':'usd'}
GBPNZD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'GBPNZD','first_currency':'gbp','second_currency':'nzd'}

USDCHF = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'USDCHF','first_currency':'usd','second_currency':'chf'}
USDJPY = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'USDJPY','first_currency':'usd','second_currency':'jpy'}
AUDUSD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'AUDUSD','first_currency':'aud','second_currency':'usd'}
NZDUSD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'NZDUSD','first_currency':'nzd','second_currency':'usd'}
USDCAD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'USDCAD','first_currency':'usd','second_currency':'cad'}

AUDJPY = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'AUDJPY','first_currency':'aud','second_currency':'jpy'}
CADJPY = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'CADJPY','first_currency':'cad','second_currency':'jpy'}
CHFJPY = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'CHFJPY','first_currency':'chf','second_currency':'jpy'}
NZDJPY = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'NZDJPY','first_currency':'nzd','second_currency':'jpy'}

AUDCHF = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'AUDCHF','first_currency':'aud','second_currency':'chf'}
CADCHF = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'CADCHF','first_currency':'cad','second_currency':'chf'}
NZDCHF = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'NZDCHF','first_currency':'nzd','second_currency':'chf'}

AUDNZD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'AUDNZD','first_currency':'aud','second_currency':'nzd'}
NZDCAD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'NZDCAD','first_currency':'nzd','second_currency':'cad'}

AUDCAD = {'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'AUDCAD','first_currency':'aud','second_currency':'cad'}

test = {
    'EURUSD':{'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURUSD','first_currency':'eur','second_currency':'usd'},
    'EURCHF':{'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURCHF','first_currency':'eur','second_currency':'chf'},
    'EURGBP':{'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURGBP','first_currency':'eur','second_currency':'gbp'},
    'EURJPY':{'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURJPY','first_currency':'eur','second_currency':'jpy'},
    'EURNZD':{'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURNZD','first_currency':'eur','second_currency':'nzd'},
    'EURAUD':{'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURAUD','first_currency':'eur','second_currency':'aud'},
    'EURCAD':{'buy':True,'sell':True,'sell_request':0,'buy_request':0,'symbol':'EURCAD','first_currency':'eur','second_currency':'cad'}
}

# %%
for i in test.values():
    print(i['symbol'])
# Out:
# EURUSD
# EURCHF
# EURGBP
# EURJPY
# EURNZD
# EURAUD
# EURCAD

# %%
test[0]['sell']
# Out:
# True

# %%
a = {
          'EURUSD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'EURUSD_High','symbol_low':'EURUSD_Low',
          'first_currency_low':'eur_low','first_currency_high':'eur_high','second_currency_low':'usd_low','second_currency_high':'usd_high'},
          'EURCHF':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'EURCHF_High','symbol_low':'EURCHF_Low',
          'first_currency_low':'eur_low','first_currency_high':'eur_high','second_currency_high':'chf_high','second_currency_low':'chf_low'},
          'EURGBP':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'EURGBP_High','symbol_low':'EURGBP_Low',
          'first_currency_low':'eur_low','first_currency_high':'eur_high','second_currency_high':'gbp_high','second_currency_low':'gbp_low'},
          'EURJPY':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'EURJPY_High','symbol_low':'EURJPY_Low',
          'first_currency_low':'eur_low','first_currency_high':'eur_high','second_currency_high':'jpy_high','second_currency_low':'jpy_low'},
          'EURNZD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'EURNZD_High','symbol_low':'EURNZD_Low',
          'first_currency_low':'eur_low','first_currency_high':'eur_high','second_currency_high':'nzd_high','second_currency_low':'nzd_low'},
          'EURAUD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'EURAUD_High','symbol_low':'EURAUD_Low',
          'first_currency_low':'eur_low','first_currency_high':'eur_high','second_currency_high':'aud_high','second_currency_low':'aud_low'},
          'EURCAD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'EURCAD_High','symbol_low':'EURCAD_Low',
          'first_currency_low':'eur_low','first_currency_high':'eur_high','second_currency_high':'cad_high','second_currency_low':'cad_low'},

          'GBPAUD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'GBPAUD_High','symbol_low':'GBPAUD_Low',
          'first_currency_low':'gbp_low','first_currency_high':'gbp_high','second_currency_high':'aud_high','second_currency_low':'aud_low'},
          'GBPCHF':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'GBPCHF_High','symbol_low':'GBPCHF_Low',
          'first_currency_low':'gbp_low','first_currency_high':'gbp_high','second_currency_high':'chf_high','second_currency_low':'chf_low'},
          'GBPJPY':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'GBPJPY_High','symbol_low':'GBPJPY_Low',
          'first_currency_low':'gbp_low','first_currency_high':'gbp_high','second_currency_high':'jpy_high','second_currency_low':'jpy_low'},
          'GBPCAD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'GBPCAD_High','symbol_low':'GBPCAD_Low',
          'first_currency_low':'gbp_low','first_currency_high':'gbp_high','second_currency_high':'cad_high','second_currency_low':'cad_low'},
          'GBPUSD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'GBPUSD_High','symbol_low':'GBPUSD_Low',
          'first_currency_low':'gbp_low','first_currency_high':'gbp_high','second_currency_high':'usd_high','second_currency_low':'usd_low'},
          'GBPNZD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'GBPNZD_High','symbol_low':'GBPNZD_Low',
          'first_currency_low':'gbp_low','first_currency_high':'gbp_high','second_currency_high':'nzd_high','second_currency_low':'nzd_low'},

          'USDCHF':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'USDCHF_High','symbol_low':'USDCHF_Low',
          'first_currency_low':'usd_low','first_currency_high':'usd_high','second_currency_high':'chf_high','second_currency_low':'chf_low'},
          'USDJPY':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'USDJPY_High','symbol_low':'USDJPY_Low',
          'first_currency_low':'usd_low','first_currency_high':'usd_high','second_currency_high':'jpy_high','second_currency_low':'jpy_low'},
          'AUDUSD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'AUDUSD_High','symbol_low':'AUDUSD_Low',
          'first_currency_low':'aud_low','first_currency_high':'aud_high','second_currency_high':'usd_high','second_currency_low':'usd_low'},
          'NZDUSD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'NZDUSD_High','symbol_low':'NZDUSD_Low',
          'first_currency_low':'nzd_low','first_currency_high':'nzd_high','second_currency_high':'usd_high','second_currency_low':'usd_low'},
          'USDCAD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'USDCAD_High','symbol_low':'USDCAD_Low',
          'first_currency_low':'usd_low','first_currency_high':'usd_high','second_currency_high':'cad_high','second_currency_low':'cad_low'},

          'AUDJPY':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'AUDJPY_High','symbol_low':'AUDJPY_Low',
          'first_currency_low':'aud_low','first_currency_high':'aud_high','second_currency_high':'jpy_high','second_currency_low':'jpy_low'},
          'CADJPY':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'CADJPY_High','symbol_low':'CADJPY_Low',
          'first_currency_low':'cad_low','first_currency_high':'cad_high','second_currency_high':'jpy_high','second_currency_low':'jpy_low'},
          'CHFJPY':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'CHFJPY_High','symbol_low':'CHFJPY_Low',
          'first_currency_low':'chf_low','first_currency_high':'chf_high','second_currency_high':'jpy_high','second_currency_low':'jpy_low'},
          'NZDJPY':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'NZDJPY_High','symbol_low':'NZDJPY_Low',
          'first_currency_low':'nzd_low','first_currency_high':'nzd_high','second_currency_high':'jpy_high','second_currency_low':'jpy_low'},

          'AUDCHF':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'AUDCHF_High','symbol_low':'AUDCHF_Low',
          'first_currency_low':'aud_low','first_currency_high':'aud_high','second_currency_high':'chf_high','second_currency_low':'chf_low'},
          'CADCHF':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'CADCHF_High','symbol_low':'CADCHF_Low',
          'first_currency_low':'cad_low','first_currency_high':'cad_high','second_currency_high':'chf_high','second_currency_low':'chf_low'},
          'NZDCHF':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'NZDCHF_High','symbol_low':'NZDCHF_Low',
          'first_currency_low':'nzd_low','first_currency_high':'nzd_high','second_currency_high':'chf_high','second_currency_low':'chf_low'},

          'AUDNZD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'AUDNZD_High','symbol_low':'AUDNZD_Low',
          'first_currency_low':'aud_low','first_currency_high':'aud_high','second_currency_high':'nzd_high','second_currency_low':'nzd_low'},
          'NZDCAD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'NZDCAD_High','symbol_low':'NZDCAD_Low',
          'first_currency_low':'nzd_low','first_currency_high':'nzd_high','second_currency_high':'cad_high','second_currency_low':'cad_low'},

          'AUDCAD':{'buy':True,'sell':True,'buy_price':0,'sell_price':0,'symbol_high':'AUDCAD_High','symbol_low':'AUDCAD_Low',
          'first_currency_low':'aud_low','first_currency_high':'aud_high','second_currency_high':'cad_high','second_currency_low':'cad_low'},
}

# %%
if h['second_currency'] in ['jpy_low','jpy_high']
    elif data[h['first_currency_low']].iloc[i] < -best_time and data[h['second_currency_high']].iloc[i] > best_time and  h['buy']:
        if not  h['sell']:
            balance_backtest = account_balance(balance_backtest,risk,leverage,h['sell_price'],data[h['symbol_low']].iloc[i],jpy=True)
            list_backtest.append(balance_backtest)
            h['buy_price'] = data[h['symbol_low']].iloc[i]
            h['sell_price'] = 0
            h['sell'] = True
            h['buy'] = False
        else:
            h['buy_price'] = data[h['symbol_low']].iloc[i]
            h['buy'] = False
    elif data[h['first_currency_high']].iloc[i] > best_time and data[h['second_currency_low']].iloc[i] < -best_time and h['sell']:
        if not h['buy']:
            balance_backtest = account_balance(balance_backtest,risk,leverage,data[h['symbol_high']].iloc[i],h['buy_price'],jpy=True)
            list_backtest.append(balance_backtest)
            h['sell_price'] = data[h['symbol_high']].iloc[i]
            h['buy_price'] = 0
            h['buy'] = True
            h['sell'] = False
        else:
            h['sell_price'] = data[h['symbol_high']].iloc[i]
            h['sell'] = False
elif not h['second_currency'] in ['jpy_low','jpy_high']
    elif data[h['first_currency_low']].iloc[i] < -best_time and data[h['second_currency_high']].iloc[i] > best_time and  h['buy']:
        if not  h['sell']:
            balance_backtest = account_balance(balance_backtest,risk,leverage,h['sell_price'],data[h['symbol_low']].iloc[i])
            list_backtest.append(balance_backtest)
            h['buy_price'] = data[h['symbol_low']].iloc[i]
            h['sell_price'] = 0
            h['sell'] = True
            h['buy'] = False
        else:
            h['buy_price'] = data[h['symbol_low']].iloc[i]
            h['buy'] = False
    elif data[h['first_currency_high']].iloc[i] > best_time and data[h['second_currency_low']].iloc[i] < -best_time and h['sell']:
        if not h['buy']:
            balance_backtest = account_balance(balance_backtest,risk,leverage,data[h['symbol_high']].iloc[i],h['buy_price'])
            list_backtest.append(balance_backtest)
            h['sell_price'] = data[h['symbol_high']].iloc[i]
            h['buy_price'] = 0
            h['buy'] = True
            h['sell'] = False
        else:
            h['sell_price'] = data[h['symbol_high']].iloc[i]
            h['sell'] = False
