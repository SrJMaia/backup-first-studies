# %% [markdown]
# # Entrada de Dados e Bibliotecas

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/Projetos/Data/EURUSD_H1_201001040000_202012182100.csv',sep='\t').drop(['<VOL>','<SPREAD>'],axis=1).rename(columns=({'<DATE>':'Date','<TIME>':'Time','<OPEN>':'Open','<HIGH>':'High','<LOW>':'Low','<CLOSE>':'Close','<TICKVOL>':'TickVol'}))
data
# Out:
#              Date      Time     Open     High      Low    Close  TickVol
# 0      2010.01.04  00:00:00  1.43259  1.43336  1.43151  1.43153      969
# 1      2010.01.04  01:00:00  1.43151  1.43153  1.42879  1.42886     2098
# 2      2010.01.04  02:00:00  1.42885  1.42885  1.42569  1.42705     2082
# 3      2010.01.04  03:00:00  1.42702  1.42989  1.42700  1.42939     1544
# 4      2010.01.04  04:00:00  1.42938  1.42968  1.42718  1.42848     1131
# ...           ...       ...      ...      ...      ...      ...      ...
# 67994  2020.12.18  17:00:00  1.22376  1.22473  1.22267  1.22350     4754
# 67995  2020.12.18  18:00:00  1.22350  1.22362  1.22256  1.22353     3614
# 67996  2020.12.18  19:00:00  1.22354  1.22459  1.22328  1.22368     1920
# 67997  2020.12.18  20:00:00  1.22367  1.22434  1.22363  1.22421     1203
# 67998  2020.12.18  21:00:00  1.22423  1.22433  1.22349  1.22422     1162
#
# [67999 rows x 7 columns]

# %%
plt.rcParams['figure.figsize'] = (50,15)
plt.style.use('dark_background')

# %% [markdown]
# # Teste 1
# - Group By para ver distribuiçãão dos preços

# %%
close = data['Close'].copy()
close.hist(bins=100,xlabelsize=10)

# %%
close.plot.kde()

# %%
sns.histplot(close, kde = True,bins=200)
plt.xticks(np.arange(1, 1.5, 0.01))
# Out:
# ([<matplotlib.axis.XTick at 0x7f2a01be0198>,
# ...
#  <a list of 50 Text major ticklabel objects>)

# %%
plt.hist(close,bins=200)
plt.xticks(np.arange(1, 2, 0.5))
# Out:
# ([<matplotlib.axis.XTick at 0x7f2a020aeeb8>,
# ...
#  <a list of 2 Text major ticklabel objects>)
