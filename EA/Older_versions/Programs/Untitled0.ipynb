# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/prices_rolling5.csv').drop(columns=('Unnamed: 0'))
df.head()
# Out:
#     eur   gbp  usd   jpy   chf  nzd  aud   cad
# 0 -10.0   2.0  3.0 -15.0  -9.0 -0.0 -2.0  -0.0
# 1  -6.0   9.0  4.0  -5.0 -13.0  2.0 -3.0   1.0
# 2  -7.0  12.0  1.0 -20.0 -16.0 -4.0 -6.0   1.0
# 3   4.0  21.0  8.0  37.0  -6.0  4.0 -0.0   7.0
# 4   6.0  22.0  8.0  63.0   5.0  3.0  5.0  14.0

# %%
df.describe()
# Out:
#                eur          gbp  ...          aud          cad
# count  6696.000000  6696.000000  ...  6696.000000  6696.000000
# mean      1.087216     1.021953  ...     0.909349     0.465502
# std      28.609991    42.866247  ...    27.553237    22.517951
# min    -189.000000  -317.000000  ...  -272.000000  -236.000000
# 25%     -14.000000   -19.000000  ...   -12.000000   -10.000000
# 50%       1.000000     1.000000  ...     1.000000     1.000000
# 75%      15.000000    22.000000  ...    14.000000    11.000000
# max     178.000000   275.000000  ...   205.000000   165.000000
#
# [8 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# eur    0
# gbp    0
# usd    0
# jpy    0
# chf    0
# nzd    0
# aud    0
# cad    0
# dtype: int64

# %%
len(df)
# Out:
# 6696

# %%
df * 10
# Out:
#         eur    gbp    usd     jpy    chf    nzd    aud    cad
# 0    -100.0   20.0   30.0  -150.0  -90.0   -0.0  -20.0   -0.0
# 1     -60.0   90.0   40.0   -50.0 -130.0   20.0  -30.0   10.0
# 2     -70.0  120.0   10.0  -200.0 -160.0  -40.0  -60.0   10.0
# 3      40.0  210.0   80.0   370.0  -60.0   40.0   -0.0   70.0
# 4      60.0  220.0   80.0   630.0   50.0   30.0   50.0  140.0
# ...     ...    ...    ...     ...    ...    ...    ...    ...
# 6691  -20.0  -80.0   50.0    60.0   50.0   40.0   -0.0   10.0
# 6692   80.0   60.0  150.0  1150.0   90.0  280.0  250.0  240.0
# 6693  410.0   50.0  350.0  2120.0  320.0  350.0  270.0  360.0
# 6694  620.0  210.0  250.0  2670.0  460.0  390.0  300.0  440.0
# 6695  670.0  310.0  250.0  2900.0  420.0  420.0  290.0  520.0
#
# [6696 rows x 8 columns]

# %%
df.describe()
# Out:
#                eur          gbp  ...          aud          cad
# count  6696.000000  6696.000000  ...  6696.000000  6696.000000
# mean      1.087216     1.021953  ...     0.909349     0.465502
# std      28.609991    42.866247  ...    27.553237    22.517951
# min    -189.000000  -317.000000  ...  -272.000000  -236.000000
# 25%     -14.000000   -19.000000  ...   -12.000000   -10.000000
# 50%       1.000000     1.000000  ...     1.000000     1.000000
# 75%      15.000000    22.000000  ...    14.000000    11.000000
# max     178.000000   275.000000  ...   205.000000   165.000000
#
# [8 rows x 8 columns]

# %%
df.head(50)
# Out:
#      eur    gbp   usd    jpy   chf   nzd   aud   cad
# 0  -10.0    2.0   3.0  -15.0  -9.0  -0.0  -2.0  -0.0
# 1   -6.0    9.0   4.0   -5.0 -13.0   2.0  -3.0   1.0
# 2   -7.0   12.0   1.0  -20.0 -16.0  -4.0  -6.0   1.0
# 3    4.0   21.0   8.0   37.0  -6.0   4.0  -0.0   7.0
# 4    6.0   22.0   8.0   63.0   5.0   3.0   5.0  14.0
# 5   13.0   20.0  10.0   65.0  12.0  -5.0   2.0  14.0
# 6    0.0    6.0   7.0   13.0  10.0 -12.0  -0.0   3.0
# 7  -18.0  -13.0   6.0  -76.0  -3.0 -28.0 -12.0  -7.0
# 8  -18.0  -24.0  -0.0  -96.0 -12.0 -28.0  -9.0  -4.0
# 9  -26.0  -61.0  -9.0 -183.0 -25.0 -27.0 -16.0 -19.0
# 10 -51.0  -97.0 -17.0 -252.0 -37.0 -16.0 -19.0 -23.0
# 11 -58.0  -96.0 -54.0 -346.0 -48.0 -30.0 -32.0 -33.0
# 12 -59.0 -127.0 -35.0 -332.0 -49.0 -21.0 -29.0 -23.0
# 13 -55.0 -105.0 -27.0 -303.0 -47.0 -25.0 -28.0 -23.0
# 14 -48.0  -63.0 -18.0 -231.0 -40.0 -25.0 -28.0 -13.0
# 15 -22.0  -37.0 -13.0 -143.0 -25.0 -21.0 -20.0  -7.0
# 16  -3.0  -19.0  27.0   31.0   3.0   2.0   2.0  15.0
# ...

# %%
# !pip install MetaTrader5
# Out:
# ERROR: Could not find a version that satisfies the requirement MetaTrader5 (from versions: none)
# ERROR: No matching distribution found for MetaTrader5
