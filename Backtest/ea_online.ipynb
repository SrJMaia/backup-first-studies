# %%
from arquivos.expert import eaonline

# %%
ea = eaonline(risk=0.01, multiply=2, magic_number=1005, timeframe='H1', tpsl = 50)

# %%
ea.start()
# Out:
# Dados Baixados com Sucesso.
# {'action': 1, 'symbol': 'EURUSD', 'volume': 0.01, 'type': 0, 'price': 1.1982, 'sl': 1.1957, 'tp': 1.2031999999999998, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order EURUSD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'EURCHF', 'volume': 0.01, 'type': 0, 'price': 1.10585, 'sl': 1.10335, 'tp': 1.11085, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order EURCHF: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'EURGBP', 'volume': 0.01, 'type': 0, 'price': 0.86863, 'sl': 0.8661300000000001, 'tp': 0.87363, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order EURGBP: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'EURJPY', 'volume': 0.01, 'type': 0, 'price': 130.552, 'sl': 130.302, 'tp': 131.052, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order EURJPY: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'EURNZD', 'volume': 0.01, 'type': 0, 'price': 1.6769699999999998, 'sl': 1.67447, 'tp': 1.6819699999999997, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order EURNZD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'EURAUD', 'volume': 0.01, 'type': 0, 'price': 1.5495999999999999, 'sl': 1.5471, 'tp': 1.5545999999999998, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order EURAUD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'EURCAD', 'volume': 0.01, 'type': 0, 'price': 1.49878, 'sl': 1.49628, 'tp': 1.50378, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order EURCAD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'GBPAUD', 'volume': 0.01, 'type': 1, 'price': 1.7839, 'sl': 1.7864, 'tp': 1.7789000000000001, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order GBPAUD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'GBPCHF', 'volume': 0.01, 'type': 1, 'price': 1.27304, 'sl': 1.27554, 'tp': 1.26804, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order GBPCHF: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'GBPJPY', 'volume': 0.01, 'type': 0, 'price': 150.301, 'sl': 150.051, 'tp': 150.801, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order GBPJPY: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'GBPCAD', 'volume': 0.01, 'type': 1, 'price': 1.7253699999999998, 'sl': 1.7278699999999998, 'tp': 1.72037, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order GBPCAD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'GBPUSD', 'volume': 0.01, 'type': 0, 'price': 1.37942, 'sl': 1.3769200000000001, 'tp': 1.38442, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order GBPUSD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'GBPNZD', 'volume': 0.01, 'type': 0, 'price': 1.9306100000000002, 'sl': 1.9281100000000002, 'tp': 1.93561, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order GBPNZD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'USDCHF', 'volume': 0.01, 'type': 1, 'price': 0.92291, 'sl': 0.92541, 'tp': 0.91791, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order USDCHF: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'USDJPY', 'volume': 0.01, 'type': 0, 'price': 108.957, 'sl': 108.707, 'tp': 109.457, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order USDJPY: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'AUDUSD', 'volume': 0.01, 'type': 0, 'price': 0.77326, 'sl': 0.77076, 'tp': 0.77826, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order AUDUSD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'NZDUSD', 'volume': 0.01, 'type': 1, 'price': 0.71451, 'sl': 0.7170099999999999, 'tp': 0.70951, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order NZDUSD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'USDCAD', 'volume': 0.01, 'type': 1, 'price': 1.25084, 'sl': 1.25334, 'tp': 1.24584, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order USDCAD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'AUDJPY', 'volume': 0.01, 'type': 0, 'price': 84.253, 'sl': 84.003, 'tp': 84.753, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order AUDJPY: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'CADJPY', 'volume': 0.01, 'type': 0, 'price': 87.11, 'sl': 86.86, 'tp': 87.61, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order CADJPY: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'CHFJPY', 'volume': 0.01, 'type': 0, 'price': 118.061, 'sl': 117.811, 'tp': 118.561, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order CHFJPY: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'NZDJPY', 'volume': 0.01, 'type': 0, 'price': 77.855, 'sl': 77.605, 'tp': 78.355, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order NZDJPY: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'AUDCHF', 'volume': 0.01, 'type': 1, 'price': 0.71361, 'sl': 0.7161099999999999, 'tp': 0.70861, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order AUDCHF: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'CADCHF', 'volume': 0.01, 'type': 0, 'price': 0.73785, 'sl': 0.7353500000000001, 'tp': 0.74285, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order CADCHF: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'NZDCHF', 'volume': 0.01, 'type': 1, 'price': 0.65942, 'sl': 0.66192, 'tp': 0.65442, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order NZDCHF: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'AUDNZD', 'volume': 0.01, 'type': 0, 'price': 1.0822, 'sl': 1.0797, 'tp': 1.0872, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order AUDNZD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'NZDCAD', 'volume': 0.01, 'type': 1, 'price': 0.8937, 'sl': 0.8962, 'tp': 0.8887, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order NZDCAD: (1, 'Success') | Code: 10030
# {'action': 1, 'symbol': 'AUDCAD', 'volume': 0.01, 'type': 1, 'price': 0.96718, 'sl': 0.96968, 'tp': 0.96218, 'deviation': 10, 'magic': 1005, 'comment': 'MAYBE LATER A COMMENT', 'type_time': 0, 'type_filling': 2}
# Error Order AUDCAD: (1, 'Success') | Code: 10030
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
# Erro ao obter dados.
